# %% [markdown]
# # NLP - Bennett University Lab - 2
# ``Harsh Dubey - E20bca021``
#
# * Create co-occurrence matrix
# * SVD
# * PCA and word2vec

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("PoetryFoundationData.csv")
data.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  \r\r\n                    Objects Used to Prop...
# 1           1  \r\r\n                    The New Church\r\r\n...
# 2           2  \r\r\n                    Look for Me\r\r\n   ...
# 3           3  \r\r\n                    Wild Life\r\r\n     ...
# 4           4  \r\r\n                    Umbrella\r\r\n      ...
#
#                                                 Poem              Poet Tags
# 0  \r\r\nDog bone, stapler,\r\r\ncribbage board, ...  Michelle Menting  NaN
# 1  \r\r\nThe old cupola glinted above the clouds,...     Lucia Cherciu  NaN
# 2  \r\r\nLook for me under the hood\r\r\nof that ...        Ted Kooser  NaN
# 3  \r\r\nBehind the silo, the Mother Rabbit\r\r\n...   Grace Cavalieri  NaN
# 4  \r\r\nWhen I push your button\r\r\nyou fly off...      Connie Wanek  NaN

# %%
data.drop(["Unnamed: 0", "Tags", "Poet"], axis=1, inplace=True)
data.head()
# Out:
#                                                Title  \
# 0  \r\r\n                    Objects Used to Prop...
# 1  \r\r\n                    The New Church\r\r\n...
# 2  \r\r\n                    Look for Me\r\r\n   ...
# 3  \r\r\n                    Wild Life\r\r\n     ...
# 4  \r\r\n                    Umbrella\r\r\n      ...
#
#                                                 Poem
# 0  \r\r\nDog bone, stapler,\r\r\ncribbage board, ...
# 1  \r\r\nThe old cupola glinted above the clouds,...
# 2  \r\r\nLook for me under the hood\r\r\nof that ...
# 3  \r\r\nBehind the silo, the Mother Rabbit\r\r\n...
# 4  \r\r\nWhen I push your button\r\r\nyou fly off...

# %%
data.shape
tokens = {} # format words: [index_no, counts]
# Out:
# (13854, 2)

# %% [markdown]
# ### Processing Text

# %%
index = 0

for i in data:
    for j in range(len(data[i])):
        words = data[i][j].split()
        for w in words:
            if w not in tokens:
                tokens[w] = [index, 1]
                index += 1
            else: tokens[w][1] += 1
        data[i][j] = " ".join(words).lstrip()
data.head()
# Out:
#                                 Title  \
# 0  Objects Used to Prop Open a Window
# 1                      The New Church
# 2                         Look for Me
# 3                           Wild Life
# 4                            Umbrella
#
#                                                 Poem
# 0  Dog bone, stapler, cribbage board, garlic pres...
# 1  The old cupola glinted above the clouds, shone...
# 2  Look for me under the hood of that old Chevrol...
# 3  Behind the silo, the Mother Rabbit hunches lik...
# 4  When I push your button you fly off the handle...

# %%
print(len(tokens))
# Out:
# 280450

# %%
def co_occurrence_matrix(window_size=1):
    matrix = np.zeros((len(tokens), len(tokens)), np.float64)

# %%
print(data["Poem"][0])
# Out:
# Dog bone, stapler, cribbage board, garlic press because this window is loose—lacks suction, lacks grip. Bungee cord, bootstrap, dog leash, leather belt because this window had sash cords. They frayed. They broke. Feather duster, thatch of straw, empty bottle of Elmer's glue because this window is loud—its hinges clack open, clack shut. Stuffed bear, baby blanket, single crib newel because this window is split. It's dividing in two. Velvet moss, sagebrush, willow branch, robin's wing because this window, it's pane-less. It's only a frame of air.
